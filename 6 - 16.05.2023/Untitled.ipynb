# %% [markdown]
# # Bài 1
# ![image.png](attachment:image.png)

# %%
diem_toan=9.5
diem_ly=7
diem_hoa=4
DTB = (diem_toan+diem_ly+diem_hoa)/3
print(DTB)
print(DTB>=8)
print(6<=DTB<8)
print(DTB<6)
# Out:
# 6.833333333333333
# False
# True
# False

# %%
diem_toan=9.5
diem_ly=7
diem_hoa=4
DTB = (diem_toan+diem_ly+diem_hoa)/3
print(DTB)
# Out:
# 6.833333333333333

# %% [markdown]
# # Bài 2
# ![image.png](attachment:image.png)

# %%
a = 60
b = 80 
c = 7
print(a>=75 and b==80 and c>=7)
# Out:
# False

# %% [markdown]
# # b

# %% [markdown]
# # b

# %% [markdown]
# # Bài 3
# ![image.png](attachment:image.png)

# %% [markdown]
# #![image.png](attachment:image.png)

# %%
a=60 #60 phút
b=33 #33km
c=1 # 1 phút
d=72 # 1 hour 12 mins

TBM=(c*b)/a 
Totalkm=d*TB #km after1h12mins

print(TBM*1000,"m/m")
print(Totalkm,"km")
# Out:
# 550.0 m/m
# 39.6 km

# %%
a=60 #60 phút
b=33 #33km
c=1 # 1 phút
d=72 # 1 hour 12 mins

# %% [markdown]
# # Bài 4![image.png](attachment:image.png)

# %%
a=16 #chieu dai
b=10 #chieu rong
S1=a*b
a+=4
S2=a*b
percentage_Variation=(S2-S1)/S1*100

print(percentage_Variation,"%")
# Out:
# 25.0 %

# %% [markdown]
# # Bài 5
# ![image.png](attachment:image.png)

# %%
v_xe_may=36
v_xe_dap=12
khoang_cach=48
hieu_van_toc= v_xe_may - v_xe_dap
t=khoang_cach/hieu_van_toc
print(t)
# Out:
# 2.0
