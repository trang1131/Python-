# %% [markdown]
# # Thực hành: Cấu trúc điều kiện

# %% [markdown]
# ### Bài 1: Viết chương trình nhập vào chiều dài và chiều rộng của hình chữ nhật và cho biết đó có phải là hình vuông hay không.![image.png](attachment:image.png)

# %%
chieu_dai = int(input("Vui lòng nhập chiều dài: "))
chieu_rong = int(input("vui lòng nhập chiều rông: "))
if chieu_dai == chieu_rong:
    print("hình vuông")
else:
    print("không phải hình vuông")
# Out:
# Vui lòng nhập chiều dài: 5
# vui lòng nhập chiều rông: 5
# hình vuông

# %% [markdown]
# ### Bài 2: Viết chương trình nhập vào 2 số a, b và in ra số lớn nhất
# ![image.png](attachment:image.png)

# %%
a= int(input("Vui lòng nhập số nguyên a: "))
b = int(input("Vui lòng nhập số nguyên b: "))
if a>b:
    print(a)
else:
    print(b)
# Out:
# Vui lòng nhập số nguyên a: 10
# Vui lòng nhập số nguyên b: 5
# 10

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào 3 số a, b, c và in ra số lớn nhất
# ![image.png](attachment:image.png)

# %%
a= int(input("Vui lòng nhập số nguyên a: "))
b = int(input("Vui lòng nhập số nguyên b: "))
c = int(input("Vui lòng nhập số nguyên c: "))
if a>=b and a>=c:
    print(f"{a} là số có giá trị lớn nhất")
elif b>=a and b>=c:
    print(f"{b} là số có giá trị lớn nhất")
else:
    print(f"{c} là số có giá trị lớn nhất")
# Out:
# Vui lòng nhập số nguyên a: 10
# Vui lòng nhập số nguyên b: 15
# Vui lòng nhập số nguyên c: 10
# 15 là số có giá trị lớn nhất

# %% [markdown]
# ### Bài 4: Viết chương trình nhập vào số tuổi của 3 người và cho biết ai là người trẻ nhất và ai là người lớn tuổi nhất![image.png](attachment:image.png)

# %%
a = int(input("Vui lòng nhập số tuổi người A: "))

b = int(input("Vui lòng nhập số tuổi người B: "))

c = int(input("Vui lòng nhập số tuổi người C: "))
if a>b>c:
    print(f"Người có tuổi {a} là người lớn tuổi nhất và người có tuổi {c} là bé nhất")
elif a>c>b:
    print(f"Người có tuổi {c} là người lớn tuổi nhất và người có tuổi {a} là bé nhất")
elif c>b>a:
    print(f"Người có tuổi {c} là người lớn tuổi nhất và người có tuổi {a} là bé nhất")
elif c>a>b:
    print(f"Người có tuổi {c} là người lớn tuổi nhất và người có tuổi {b} là bé nhất")
elif b>a>c:
    print(f"Người có tuổi {b} là người lớn tuổi nhất và người có tuổi {c} là bé nhất")
elif b>c>a:
    print(f"Người có tuổi {b} là người lớn tuổi nhất và người có tuổi {a} là bé nhất")                     
else:
    print("Vui lòng nhập 3 số tuổi khác nhau để hoàn thành so sánh")
# Out:
# Vui lòng nhập số tuổi người A: 10
# Vui lòng nhập số tuổi người B: 5
# Vui lòng nhập số tuổi người C: 1
# Người có tuổi 10 là người lớn tuổi nhất và người có tuổi 1 là bé nhất

# %% [markdown]
# ### Bài 5: Viết chương trình nhập vào một số bất kỳ và in ra giá trị tuyệt đối của số đó

# %%
a=eval(input("Enter your number: "))
if a>=0:
    print(a)
if a<0:
    print(-a)
# Out:
# Enter your number: -11
# 11

# %% [markdown]
# ### Bài 6: Học viên sẽ không đủ điều kiện thi nếu tỉ lệ có mặt nhỏ hơn 75%. Viết chương trình nhập vào tổng số buổi học của một khóa học và tổng số buổi học mà học viên tham gia. Sau đó cho biết học viên đó có đủ điều kiện thi hay không.

# %%
a = int(input("Vui lòng điền tổng số buổi học của khóa: "))
b = int(input("Vui lòng điền vào sô buổi học bạn hoàn thành: "))
if b>=(a*0.75): 
    print("Đủ điều kiện thi")
else: 
    print("Không đủ điều kiện thi")
# Out:
# Vui lòng điền tổng số buổi học của khóa: 100
# Vui lòng điền vào sô buổi học bạn hoàn thành: 76
# Đủ điều kiện thi

# %% [markdown]
# ### Bài 7: Một công ty vận tải có cách tính chi phí giao hàng như sau:
# 1. 10kilogram đầu tiên: \$5/kg
# 2. Từ kilogram thứ 11 đến 20: \$7/kg
# 3. Từ kilogram thứ 20 trở lên: \$10/kg
#
# Viết chương trình nhập vào số kg cần giao(số nguyên) và in ra chi phí giao hàng tương ứng

# %%
w = int(input(" Please input weight: "))
if w <= 10:
    print(f"Friehgt is ${w*5}")
elif w>10 and w<20:
    print(f"Freigh is ${50+(w-10)*7}")
else:
    print(f"Freight is ${50+70+(w-20)*10}")
# Out:
#  Please input weight: 10
# Friehgt is $50

# %% [markdown]
# ### Bài 8: Viết chương trình nhập vào số năm và cho biết năm đó là năm nhuận hay năm không nhuận.

# %%
y = int(input("Please input year: "))
if y % 400 == 0:
    print("Năm nhuận")
else:
    print("Không phải năm nhuận")
# Out:
# Please input year: 1900
# Không phải năm nhuận

# %% [markdown]
# ### Bài 9: Viết chương trình nhập vào 1 số từ 1 đến 7 và in ra số ngày trong tuần tương ứng như sau:
# - 1: Sunday
# - 2: Monday
# - 3: Tuesday
# - 4: Wednesday
# - 5: Thursday
# - 6: Friday
# - 7: Saturday

# %%
a = "Sunday"
b = "Monday"
c = "Tuesday"
d = "Wednesday"
e = "Thursday"
f = "Friday"
g = "Saturday"
x = int(input("nhập vào 1 số từ 1 đến 7: "))

if x == 1:
    print(a)
elif x == 2:
    print(b)
elif x == 3:
    print(c)
elif x == 4:
    print(d)
elif x == 5:
    print(e)
elif x == 6:
    print(f)
elif x == 7:
    print(g)
else:
    print("Số không hợp lệ, vui lòng chỉ nhập số từ 1 tới 7")
# Out:
# nhập vào 1 số từ 1 đến 7: 10
# Số không hợp lệ, vui lòng chỉ nhập số từ 1 tới 7

# %% [markdown]
# ### Bài 10:
# Tại một cửa hàng nọ có menu như sau:
#
# 1. Gà rán giá 35k
# 2. Hamburger giá 50k
# 3. Pesi giá 10k
#
# Nhập số lượng món hàng cần mua
#
# Tính và in ra tổng giá tiền
#
# Nếu giá trị đơn hàng trên 2 triệu, giảm 10% cho khách, trên 4 triệu, giảm 15%
#
# Tính và in ra tổng giá tiền được giảm
#
# Tính và in ra tổng giá tiền khách cần trả
#
# In ra dòng chữ "Cảm ơn quý khách đã mua hàng"

# %%
"""Ví dụ:
Nhập số lượng gà rán khách mua:100
Nhập số lượng hamburger khách mua:100
Nhập số lượng pesi khách mua:15
Tổng giá tiền đơn hàng là: 8.650.000
Tổng tiền được giảm là: 1.297.500
Tổng tiền phải thanh toán: 7.352.500
Cảm ơn quý khách đã mua
"""

# %%
x = 35000
y = 50000
z = 10000
a = int(input("Nhập số lượng gà rán khách mua: "))
b = int(input("Nhập số lượng hamburger khách mua: "))
c = int(input("Nhập số lượng pesi khách mua: "))

total = (a*x)+(b*y)+(c*z)
if total < 2000000:
    print(f"Tổng tiền phải thanh toán: ${total}")
    print("Đội ơn quý khách đã mua ♥")
elif total>2000000 and total<4000000:
    print(f"Tổng giá tiền đơn hàng là: ${total}")
    print(f"Tổng tiền được giảm là: ${total*0.1}")
    print(f"Tổng tiền phải thanh toán: ${total*0.9}")
    print("Đội ơn quý khách đã mua ♥")
else:
    print(f"Tổng giá tiền đơn hàng là: ${total}")
    print(f"Tổng tiền được giảm là: ${total*0.15}")
    print(f"Tổng tiền phải thanh toán: ${total*0.85}")
    print("Đội ơn quý khách đã mua ♥")
# Out:
# Nhập số lượng gà rán khách mua: 100
# Nhập số lượng hamburger khách mua: 100
# Nhập số lượng pesi khách mua: 15
# Tổng giá tiền đơn hàng là: $8650000
# Tổng tiền được giảm là: $1297500.0
# Tổng tiền phải thanh toán: $7352500.0
# Đội ơn quý khách đã mua ♥

# %% [markdown]
# ### Bài 11:
#
# Nhập vào chiều cao (cm) và cân nặng (kg), tính số BMI và xét rồi xin kết quả theo dữ liệu sau:
#
# - BMI < 16: Gầy cấp độ III
# - 16 <= BMI < 17:  Gầy cấp độ II
# - 17<= BMI < 18.5: Gầy cấp độ I
# - 18.5 <= BMI < 25: Bình thường
# - 25 <= BMI < 30: Thừa cân
# - 30 <= BMI < 35 : Béo phì cấp độ I
# - 35 <= BMI < 40: Béo phì cấp độ II
# - BMI > 40: Béo phì cấp độ III

# %%
w = eval(input("Nhập vào cân nặng (theo kg): "))
h = eval(input("Nhập vào chiều cao(theo m): "))
bmi = w/(h*h)
if bmi < 16:
    print("Gầy cấp độ 3")
elif bmi >= 16 and bmi<17:
    print("Gầy cấp độ 2")
elif bmi >= 17 and bmi<18.5:
    print("Gầy cấp độ 1")
elif bmi >= 18.5 and bmi<25:
    print("Bình thường")
elif bmi >= 25 and bmi<30:
    print("Thừa cân")
elif bmi >= 30 and bmi<35:
    print(" Béo phì cấp độ I") 
elif bmi >= 35 and bmi<40:
    print("Béo phì cấp độ II")
else:
    print("Béo phì cấp độ III")
# Out:
# Nhập vào cân nặng (theo kg): 50
# Nhập vào chiều cao(theo m): 1.6
# Bình thường

# %% [markdown]
# ### Bài 12: Tìm ra người lớn tuổi nhất trong 4 người thông qua số tuổi nhập vào từ người dùng.

# %%
a = int(input("Người A: "))
b = int(input("Người B: "))
c = int(input("Người C: "))
d = int(input("Người D: "))
e = int(input("Người E: "))
list = [a,b,c,d,e]
print(f"Người lớn nhất là người có số tuổi {max(list)}")
# Out:
# Người A: 10
# Người B: 9
# Người C: 8
# Người D: 9
# Người E: 15
# Người lớn nhất là người có số tuổi 15

# %% [markdown]
# ## BONUS

# %% [markdown]
# ### Bài 13: Viết chương trình nhập vào số đo 3 cạnh của tam giác và cho biết đó là tam giác cân, tam giác đều hay tam giác vô hướng
# Ghi chú:
#  - Tam giác cân là tam giác có 2 cạnh bằng nhau
#  - Tam giác đều là tam giác có 3 cạnh bằng nhau
#  - Tam giác vô hướng là tam giác không có cạnh nào bằng nhau

# %%
#Bài này hoỉ thầy vì sao ngược lại thì hk work:
a = int(input("Nhập cạnh 1 của tam giác (cm): "))
b = int(input("Nhập cạnh 2 của tam giác (cm): "))
c = int(input("Nhập cạnh 3 của tam giác (cm): "))

if a==b and b==c:
    print("Tam giác đều")
elif a==b or a==c or b==c:
    print("Tam giác cân")
else:
    print("Tam giác vô hướng")

# %% [markdown]
# ### Bài 14: Viết chương trình nhập vào 3 số nguyên khác nhau và in ra số lớn thứ hai

# %%
a= int(input("Vui lòng nhập số nguyên a: "))
b = int(input("Vui lòng nhập số nguyên b: "))
c = int(input("Vui lòng nhập số nguyên c: "))
if a>b>c:
    print(b)
elif b>a>c:
    print(a)
elif c>a>b:
    print(c)
else:
    print("Vui lòng nhập 3 số nguyên KHÁC NHAU")
# Out:
# Vui lòng nhập số nguyên a: 10
# Vui lòng nhập số nguyên b: 9
# Vui lòng nhập số nguyên c: 8
# 9

# %% [markdown]
# ### Bài 15: Xem đoạn code sau:
# ![image.png](attachment:image.png)
# Nếu i, j, k có các giá trị ban đầu là:
#
# a. i = 3, j = 5, k = 7
#
# b. i = 13, j = 15, k = 13
#
# Thì giá trị của i, j, k sau khi thực hiện đoạn code trên là bao nhiêu?(kiểm tra bằng cách tính nhẩm, không code lại)

# %%
# nếu giá trị ban đầu là 3,5,7 sau code sẽ là i=j nên 3=5?
#nếu giá trị ban đầu là 13,15,13 sau code sẽ là j=i 
i = 3
j = 5
k=7

if i<j:
    if j<k:
        i = j
    else:
        j = k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       7 if i<j:
#       8     if j<k:
# ----> 9         print(i = j)
#      10     else:
#      11         j = k
#
# TypeError: 'i' is an invalid keyword argument for print()

# %% [markdown]
# ### Bài 16: Viết một chương trình thực hiện phép tính đơn giản như sau:
# ```
#     Nhập số thứ nhất: 16
#     Nhập số thứ hai: 9
#     Nhập toán tử (+, -, *, /): +
#     Kết quả: 16 + 9 = 25
# ```

# %%
a = int(input("Nhập số thứ nhất: "))
b = int(input("Nhập số thứ hai: "))
c = input("Nhập toán tử:(+, -, *, /): +:  ")
d = a + b
if c == "+" :
    print(f"{a} + {b} = {d}")
# Out:
# Nhập số thứ nhất: 10
# Nhập số thứ hai: 1
# Nhập toán tử:(+, -, *, /): +:  +
# 10 + 1 = 11

# %% [markdown]
# ### Bài 17: Viết chương trình nhập vào 3 số nguyên và in ra màn hình theo thứ tự từ lớn đến bé.

# %%
a= int(input("Vui lòng nhập số nguyên a: "))
b = int(input("Vui lòng nhập số nguyên b: "))
c = int(input("Vui lòng nhập số nguyên c: "))
if a>b>c:
    print(f"{a}>{b}>{c}")
elif a>c>b:
    print(f"{a}>{c}>{b}")
elif b>a>c:
    print(f"{b}>{a}>{c}")
elif b>c>a:
    print(f"{b}>{c}>{a}")
elif c>a>b:
    print(f"{c}>{a}>{b}")
elif c>b>a:
    print(f"{c}>{a}>{b}")
# Out:
# Vui lòng nhập số nguyên a: 1
# Vui lòng nhập số nguyên b: 15
# Vui lòng nhập số nguyên c: 14
# 15>14>1
